# %% [markdown]
# <a href="https://colab.research.google.com/github/Eunjae-Choi-0/allaboutStudy/blob/main/Python_Deep_Learning_0823(Day3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
x_data = []
y_data = []
for imgname in glob.glob('/content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/*'):
  print(imgname)
  img = Image.open(imgname).convert('L')
  img = img.resize((100,100))
  ndimg = 255-np.array(img)
  x_data.append(ndimg)
  if (imgname.split('/')[-1].startswith('man')):
    y_data.append(0)
  else:
    y_data.append(1)
  print(ndimg.shape)
  plt.imshow(ndimg, cmap='Greys')
  plt.show()
x_data = np.array(x_data)
y_data = np.array(y_data)
print(x_data.shape, y_data.shape)
# Out:
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/woman01.jpg
# (100, 100)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/woman02.jpg
# (100, 100)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/woman03.jpg
# (100, 100)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/woman04.jpg
# (100, 100)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/woman05.jpg
# (100, 100)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/man01.jpg
# (100, 100)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/man02.jpg
# (100, 100)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/man03.jpg
# (100, 100)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/man04.jpg
# (100, 100)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/man05.jpg
# (100, 100)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/test01.jpg
# ...

# %%
##내가 한거임##

import numpy as np
import matplotlib.pyplot as plt
import glob
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.utils import to_categorical

# 데이터 로딩 및 전처리
x_data = []
y_data = []

for imgname in glob.glob('/content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/*'):
  print(imgname)
  img = Image.open(imgname).convert('L')
  img = img.resize((100,100))
  ndimg = 255-np.array(img)
  x_data.append(ndimg)
  if (imgname.split('/')[-1].startswith('man')):
    y_data.append(0)
  else:
    y_data.append(1)

x_data = np.array(x_data)
y_data = np.array(y_data)

# 데이터 정규화
x_data = x_data / 255.0

# 데이터 분할
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

# 데이터 차원 추가 (채널 차원 추가)
x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

# 라벨을 원-핫 인코딩
y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)

# CNN 모델 정의
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(100, 100, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(2, activation='softmax')  # 두 클래스 (남자, 여자)
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 모델 학습
history = model.fit(x_train, y_train, epochs=20, validation_data=(x_test, y_test))

# 모델 평가
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc}")

# 학습 과정 시각화
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1.5])
plt.legend(loc='lower right')
plt.show()
# Out:
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/woman01.jpg
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/woman02.jpg
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/woman03.jpg
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/woman04.jpg
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/woman05.jpg
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/man01.jpg
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/man02.jpg
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/man03.jpg
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/man04.jpg
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/man05.jpg
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/test01.jpg
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/test02.jpg
# ...

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
x_train, x_test, y_train, y_test = train_test_split(x_data,
                                                    y_data,
                                                    stratify=y_data,
                                                    test_size=0.2)
x_train_1d = x_train.reshape(8,-1) / 255
x_test_1d =  x_test.reshape(2,-1) / 255
y_train_enc = to_categorical(y_train)
y_test_enc = to_categorical(y_test)
print(x_train_1d.shape, y_test_enc.shape)
# Out:
# (8, 12500) (3, 2)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense
model = Sequential()
model.add(Input(shape=(10000,)))
model.add(Dense(256, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(2, activation='softmax'))
model.compile(loss='binary_crossentropy',optimizer='adam',
              metrics=['accuracy'])
model.summary()
model.fit(x_train_1d, y_train_enc, validation_data=(x_test_1d, y_test_enc),epochs=10)
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_14 (Dense)                     │ (None, 256)                 │       2,560,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,576,834 (9.83 MB)
#  Trainable params: 2,576,834 (9.83 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 내 사진 추가

x_data = []
for imgname in glob.glob('/content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/test*'):
  print(imgname)
  img = Image.open(imgname).convert('L')
  img = img.resize((100,100))
  ndimg = 255-np.array(img)
  x_data.append(ndimg)
  print(ndimg.shape)
  plt.imshow(ndimg, cmap='Greys')
  plt.show()
x_data = np.array(x_data)
print(x_data.shape)
# Out:
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/test01.jpg
# (100, 100)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/test02.jpg
# (100, 100)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/test03.jpg
# (100, 100)
# (3, 100, 100)

# %%
np.argmax(model.predict(x_data.reshape(3,-1)/255), axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# array([1, 1, 1])

# %% [markdown]
# # ===========================================================

# %%
from tensorflow.keras.datasets import mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()
print(x_train.shape, y_test.shape)
# Out:
# (60000, 28, 28) (10000,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
model = Sequential()
model.add(Input(shape=(28,28,1)))
model.add(Conv2D(32, kernel_size=(3,3), padding='same',
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64, kernel_size=(3,3), padding='same',
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(10, activation='softmax'))
model.summary()
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_10 (Conv2D)                   │ (None, 28, 28, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 14, 14, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_9 (MaxPooling2D)       │ (None, 7, 7, 64)            │               0 │
# ...

# %%
x_train_norm = x_train / 255
x_test_norm = x_test / 255
y_train_enc = to_categorical(y_train)
y_test_enc = to_categorical(y_test)
model.fit(x_train_norm, y_train_enc, validation_data=(x_test_norm, y_test_enc), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 88s 46ms/step - accuracy: 0.9036 - loss: 0.3266 - val_accuracy: 0.9855 - val_loss: 0.0418
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 137s 43ms/step - accuracy: 0.9840 - loss: 0.0525 - val_accuracy: 0.9850 - val_loss: 0.0437
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 44ms/step - accuracy: 0.9889 - loss: 0.0367 - val_accuracy: 0.9888 - val_loss: 0.0334
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 141s 43ms/step - accuracy: 0.9915 - loss: 0.0280 - val_accuracy: 0.9900 - val_loss: 0.0310
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 81s 43ms/step - accuracy: 0.9939 - loss: 0.0198 - val_accuracy: 0.9895 - val_loss: 0.0319
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 82s 43ms/step - accuracy: 0.9946 - loss: 0.0152 - val_accuracy: 0.9905 - val_loss: 0.0339
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 85s 45ms/step - accuracy: 0.9966 - loss: 0.0108 - val_accuracy: 0.9893 - val_loss: 0.0379
# Epoch 8/10
# ...

# %%
x_data = []
for imgname in glob.glob('/content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/*.png'):
  print(imgname)
  img = Image.open(imgname).convert('L')
  img = img.resize((28,28))
  ndimg = 255-np.array(img)
  x_data.append(ndimg)
  print(ndimg.shape)
  plt.imshow(ndimg, cmap='Greys')
  plt.show()
x_data = np.array(x_data)
print(x_data.shape)
# Out:
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/write.png
# (28, 28)
# (1, 28, 28)

# %%
np.argmax(model.predict(x_data/255), axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# array([8])

# %%
import glob
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
x_data = []
y_data = []
for imgname in glob.glob('/content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/*'):
  print(imgname)
  img = Image.open(imgname)
  img = img.resize((100,100))
  ndimg = np.array(img)
  x_data.append(ndimg)
  if (imgname.split('/')[-1].startswith('man')):
    y_data.append(0)
  else:
    y_data.append(1)
  print(ndimg.shape)
  plt.imshow(ndimg, cmap='Greys')
  plt.show()
x_data = np.array(x_data)
y_data = np.array(y_data)
print(x_data.shape, y_data.shape)
# Out:
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/woman01.jpg
# (100, 100, 3)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/woman02.jpg
# (100, 100, 3)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/woman03.jpg
# (100, 100, 3)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/woman04.jpg
# (100, 100, 3)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/woman05.jpg
# (100, 100, 3)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/man01.jpg
# (100, 100, 3)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/man02.jpg
# (100, 100, 3)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/man03.jpg
# (100, 100, 3)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/man04.jpg
# (100, 100, 3)
# /content/drive/MyDrive/새싹/0821-0823 Python Deep Learning/celeb/man05.jpg
# (100, 100, 3)
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
model = Sequential()
model.add(Input(shape=(100,100,3)))
model.add(Conv2D(32, kernel_size=(3,3), padding='same',
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64, kernel_size=(3,3), padding='same',
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(2, activation='softmax'))
model.summary()
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 100, 100, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 50, 50, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 50, 50, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 25, 25, 64)          │               0 │
# ...

# %%
from tensorflow.keras.utils import to_categorical
x_data_norm = x_data / 255
y_data_enc = to_categorical(y_data)
model.fit(x_data_norm[:10], y_data_enc[:10],
          validation_data=(x_data_norm[10:], y_data_enc[10:]),
          epochs=30)
# Out:
# Epoch 1/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.7000 - loss: 0.6980 - val_accuracy: 1.0000 - val_loss: 0.6514
# Epoch 2/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 1.0000 - loss: 0.6072 - val_accuracy: 0.3333 - val_loss: 0.7299
# Epoch 3/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 1.0000 - loss: 0.5492 - val_accuracy: 0.3333 - val_loss: 0.7411
# Epoch 4/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 1.0000 - loss: 0.5145 - val_accuracy: 1.0000 - val_loss: 0.4957
# Epoch 5/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step - accuracy: 1.0000 - loss: 0.4023 - val_accuracy: 1.0000 - val_loss: 0.5898
# Epoch 6/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 1.0000 - loss: 0.3789 - val_accuracy: 0.3333 - val_loss: 0.6251
# Epoch 7/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 1.0000 - loss: 0.2833 - val_accuracy: 0.6667 - val_loss: 0.6312
# Epoch 8/30
# ...
